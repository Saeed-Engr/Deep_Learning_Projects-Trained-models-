# %%
import tensorflow as tf

from tensorflow import keras
from keras import layers

# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import models

model = models.Sequential()
model.add(keras.Input(shape=(180, 180, 3)))
model.add(layers.Rescaling((1./255)))

model.add(Conv2D(32, (3, 3), activation='relu', padding='same', name='conv_1'))
model.add(MaxPooling2D((2, 2), name='maxpool_1'))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same', name='conv_2'))
model.add(MaxPooling2D((2, 2), name='maxpool_2'))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same', name='conv_3'))
model.add(MaxPooling2D((2, 2), name='maxpool_3'))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same', name='conv_4'))
model.add(MaxPooling2D((2, 2), name='maxpool_4'))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same', name='conv_5'))
model.add(MaxPooling2D((2, 2), name='maxpool_5'))

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu', name='dense_1'))
model.add(Dense(128, activation='relu', name='dense_2'))
model.add(Dense(1, activation='sigmoid', name='output'))
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_17 (Rescaling)    (None, 180, 180, 3)       0
#
#  conv_1 (Conv2D)             (None, 180, 180, 32)      896
#
#  maxpool_1 (MaxPooling2D)    (None, 90, 90, 32)        0
#
#  conv_2 (Conv2D)             (None, 90, 90, 64)        18496
#
#  maxpool_2 (MaxPooling2D)    (None, 45, 45, 64)        0
#
#  conv_3 (Conv2D)             (None, 45, 45, 128)       73856
#
#  maxpool_3 (MaxPooling2D)    (None, 22, 22, 128)       0
#
#  conv_4 (Conv2D)             (None, 22, 22, 64)        73792
#
#  maxpool_4 (MaxPooling2D)    (None, 11, 11, 64)        0
#
#  conv_5 (Conv2D)             (None, 11, 11, 64)        36928
#
#  maxpool_5 (MaxPooling2D)    (None, 5, 5, 64)          0
#
#  flatten_11 (Flatten)        (None, 1600)              0
#
#  dropout_5 (Dropout)         (None, 1600)              0
#
# ...

# %%
inputs = keras.Input(shape=(512, 512, 3))
x = layers.Rescaling(1./255)(inputs) 
x = layers.Conv2D(filters=32, kernel_size=3, padding='same', strides=2, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3, padding='same', strides=1, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=3, padding='same', strides=2, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3, padding='same', strides=1, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=32, kernel_size=3, padding='same', strides=2, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Flatten()(x)
x = layers.Dense(512, activation='relu')(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_24 (InputLayer)       [(None, 512, 512, 3)]     0
#
#  rescaling_19 (Rescaling)    (None, 512, 512, 3)       0
#
#  conv2d_71 (Conv2D)          (None, 256, 256, 32)      896
#
#  max_pooling2d_38 (MaxPoolin  (None, 128, 128, 32)     0
#  g2D)
#
#  conv2d_72 (Conv2D)          (None, 128, 128, 64)      18496
#
#  max_pooling2d_39 (MaxPoolin  (None, 64, 64, 64)       0
#  g2D)
#
#  conv2d_73 (Conv2D)          (None, 32, 32, 128)       73856
#
#  max_pooling2d_40 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  conv2d_74 (Conv2D)          (None, 16, 16, 64)        73792
#
#  max_pooling2d_41 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_75 (Conv2D)          (None, 4, 4, 32)          18464
#
#  max_pooling2d_42 (MaxPoolin  (None, 2, 2, 32)         0
#  g2D)
#
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers

inputs = keras.Input(shape=(180, 180, 3))

x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_25 (InputLayer)       [(None, 180, 180, 3)]     0
#
#  conv2d_76 (Conv2D)          (None, 178, 178, 32)      896
#
#  conv2d_77 (Conv2D)          (None, 176, 176, 32)      9248
#
#  max_pooling2d_43 (MaxPoolin  (None, 88, 88, 32)       0
#  g2D)
#
#  conv2d_78 (Conv2D)          (None, 86, 86, 64)        18496
#
#  conv2d_79 (Conv2D)          (None, 84, 84, 64)        36928
#
#  max_pooling2d_44 (MaxPoolin  (None, 42, 42, 64)       0
#  g2D)
#
#  conv2d_80 (Conv2D)          (None, 40, 40, 128)       73856
#
#  conv2d_81 (Conv2D)          (None, 38, 38, 128)       147584
#
#  max_pooling2d_45 (MaxPoolin  (None, 19, 19, 128)      0
#  g2D)
#
#  conv2d_82 (Conv2D)          (None, 17, 17, 64)        73792
#
#  conv2d_83 (Conv2D)          (None, 15, 15, 64)        36928
#
#  max_pooling2d_46 (MaxPoolin  (None, 7, 7, 64)         0
# ...
