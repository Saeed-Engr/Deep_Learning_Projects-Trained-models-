# %%
import tensorflow as tf

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model

model = load_model('mask_detection_trained_model.h5')

# %%
img = image.load_img("dataset/val/without_mask/0_0_dongchengpeng_0042.jpg", target_size=(180, 180))
x=image.img_to_array(img) / 255
resized_img_np = np.expand_dims(x,axis=0)
prediction = model.predict(resized_img_np)
print(prediction)

if prediction[0][0] > = 0.5:
    prediction = "with_mask"
else:
    prediction = "without_mask"
print(prediction)
# Out:
# [[0.6093525]]
# without_mask

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model

model = load_model('mask_model.h5')

# %%
# for only one prediction
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image
test_image = image.load_img('dataset/val/without_mask/augmented_image_35.jpg',
                            target_size=(160,160))
plt.imshow(test_image)
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = model.predict(test_image)
print(result)

if result[0][0] >= 0.5:
    prediction = 'with_mask'
else:
    prediction = 'without_mask  '
    
print(prediction)
# Out:
# [[0.04952171]]
# without_mask

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model

model = load_model('mask_model.h5')


# for only one prediction
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image
test_image = image.load_img('dataset/val/without_mask/augmented_image_185.jpg',
                            target_size=(160,160))
plt.imshow(test_image)
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = model.predict(test_image)
print(result)

if result[0][0] == 1:
    prediction = 'with_mask'
else:
    prediction = 'without_mask  '
    
print(prediction)
# Out:
# [[1.]]
# with_mask
