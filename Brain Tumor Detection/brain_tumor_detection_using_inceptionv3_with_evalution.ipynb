# %%
import tensorflow as tf
import keras 
import numpy as np
import cv2
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
path_root = "/content/drive/MyDrive/Thesis Data/Brain tumor"

from keras.preprocessing.image import ImageDataGenerator
batches = ImageDataGenerator().flow_from_directory(directory=path_root, target_size=(256, 256),batch_size=1952)
# Out:
# Found 1952 images belonging to 2 classes.

# %%
batches.class_indices
# Out:
# {'HighGrade': 0, 'Low Grade': 1}

# %%
imgs, labels = next(batches)

# %%
print(imgs.shape)
print(labels.shape)
# Out:
# (1952, 256, 256, 3)
# (1952, 2)

# %%
# plots images with labels within jupyter notebook
import numpy as np

def plots(ims, figsize=(20,30), rows=10, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != 3):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = 10 # len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(0,30):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(list(batches.class_indices.keys())[np.argmax(titles[i])], fontsize=16)
        plt.imshow(ims[i], interpolation=None if interp else 'none')

# %%
plots(imgs, titles = labels)

# %%
classes = batches.class_indices.keys()
perc = (sum(labels)/labels.shape[0])*100

plt.xticks(rotation='vertical')
plt.bar(classes,perc)
# Out:
# <BarContainer object of 2 artists>

# %%
from sklearn.model_selection import train_test_split
# Train, validation and test split

X_train, X_test, y_train, y_test = train_test_split(imgs, labels, test_size=0.15, random_state=7)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, random_state=1)

# %%
print("*-*-*-*-*-*")
print("Train")
print(X_train.shape)
print(y_train.shape)


print("*-*-*-*-*-*")
print("Validation")
print(X_val.shape)
print(y_val.shape)

print("*-*-*-*-*-*")
print("Test")
print(X_test.shape)
print(y_test.shape)
# Out:
# *-*-*-*-*-*
# Train
# (1410, 256, 256, 3)
# (1410, 2)
# *-*-*-*-*-*
# Validation
# (249, 256, 256, 3)
# (249, 2)
# *-*-*-*-*-*
# Test
# (293, 256, 256, 3)
# (293, 2)

# %%
import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
#from keras.layers.normalization import BatchNormalization
from keras.applications.resnet import ResNet50

# %%
from tensorflow.keras.applications import ResNet50
conv_base = ResNet50(weights='imagenet', include_top=False, input_shape=(256, 256,3))

from keras import models
from keras import layers
model = models.Sequential()
model.add(conv_base)
model.add(Dropout(0.25))

model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(layers.Dense(2, activation='sigmoid'))

# %%
model.compile(optimizer="rmsprop",
 loss="binary_crossentropy",
 metrics=["accuracy"])

# %%
y_train_new = np.argmax(y_train, axis=1)

# %%
history = model.fit(X_train, y_train,
                    validation_data = (X_val, y_val) ,
                    batch_size = 32, 
                    epochs = 30, 
                   )
# Out:
# Epoch 1/30
# 45/45 [==============================] - 47s 491ms/step - loss: 2.6085 - accuracy: 0.5177 - val_loss: 27.6642 - val_accuracy: 0.4980
# Epoch 2/30
# 45/45 [==============================] - 20s 435ms/step - loss: 0.7674 - accuracy: 0.5333 - val_loss: 0.9196 - val_accuracy: 0.4980
# Epoch 3/30
# 45/45 [==============================] - 20s 448ms/step - loss: 0.8170 - accuracy: 0.6872 - val_loss: 1632.0934 - val_accuracy: 0.4980
# Epoch 4/30
# 45/45 [==============================] - 21s 457ms/step - loss: 0.2723 - accuracy: 0.9028 - val_loss: 9561.9170 - val_accuracy: 0.4980
# Epoch 5/30
# 45/45 [==============================] - 20s 446ms/step - loss: 0.2864 - accuracy: 0.9333 - val_loss: 4676.8364 - val_accuracy: 0.4980
# Epoch 6/30
# 45/45 [==============================] - 20s 441ms/step - loss: 0.1842 - accuracy: 0.9574 - val_loss: 3353.8679 - val_accuracy: 0.4980
# Epoch 7/30
# 45/45 [==============================] - 20s 443ms/step - loss: 0.1166 - accuracy: 0.9688 - val_loss: 194.4665 - val_accuracy: 0.4980
# Epoch 8/30
# 45/45 [==============================] - 20s 448ms/step - loss: 0.0398 - accuracy: 0.9901 - val_loss: 6.8906 - val_accuracy: 0.8072
# Epoch 9/30
# 45/45 [==============================] - 20s 447ms/step - loss: 0.1375 - accuracy: 0.9745 - val_loss: 0.2080 - val_accuracy: 0.9799
# Epoch 10/30
# 45/45 [==============================] - 20s 445ms/step - loss: 0.0649 - accuracy: 0.9908 - val_loss: 46.4375 - val_accuracy: 0.5462
# Epoch 11/30
# 45/45 [==============================] - 20s 443ms/step - loss: 0.0082 - accuracy: 0.9957 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 12/30
# 45/45 [==============================] - 20s 443ms/step - loss: 0.4003 - accuracy: 0.9780 - val_loss: 2.1267 - val_accuracy: 0.9116
# Epoch 13/30
# 45/45 [==============================] - 20s 444ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.2289 - val_accuracy: 0.9960
# Epoch 14/30
# 45/45 [==============================] - 20s 444ms/step - loss: 0.0740 - accuracy: 0.9915 - val_loss: 0.5498 - val_accuracy: 0.9558
# Epoch 15/30
# 45/45 [==============================] - 20s 445ms/step - loss: 0.0811 - accuracy: 0.9957 - val_loss: 8.0014 - val_accuracy: 0.7671
# Epoch 16/30
# 45/45 [==============================] - 20s 449ms/step - loss: 0.1056 - accuracy: 0.9894 - val_loss: 4.3909 - val_accuracy: 0.8956
# Epoch 17/30
# 45/45 [==============================] - 20s 448ms/step - loss: 8.2860e-04 - accuracy: 1.0000 - val_loss: 0.1662 - val_accuracy: 0.9880
# Epoch 18/30
# 45/45 [==============================] - 20s 445ms/step - loss: 2.1834e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 19/30
# 45/45 [==============================] - 20s 445ms/step - loss: 4.4493e-07 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 20/30
# 45/45 [==============================] - 20s 443ms/step - loss: 1.2716e-05 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9598
# Epoch 21/30
# 45/45 [==============================] - 20s 450ms/step - loss: 0.1394 - accuracy: 0.9887 - val_loss: 0.1025 - val_accuracy: 0.9920
# Epoch 22/30
# 45/45 [==============================] - 20s 443ms/step - loss: 0.0302 - accuracy: 0.9957 - val_loss: 4.9104 - val_accuracy: 0.8956
# Epoch 23/30
# 45/45 [==============================] - 20s 444ms/step - loss: 0.0865 - accuracy: 0.9957 - val_loss: 45.8237 - val_accuracy: 0.4980
# Epoch 24/30
# 45/45 [==============================] - 20s 443ms/step - loss: 0.0421 - accuracy: 0.9950 - val_loss: 0.5376 - val_accuracy: 0.9317
# Epoch 25/30
# 45/45 [==============================] - 20s 444ms/step - loss: 0.0768 - accuracy: 0.9929 - val_loss: 0.6706 - val_accuracy: 0.9679
# Epoch 26/30
# 45/45 [==============================] - 20s 444ms/step - loss: 3.4056e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 27/30
# 45/45 [==============================] - 20s 445ms/step - loss: 1.7178e-06 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 28/30
# 45/45 [==============================] - 20s 448ms/step - loss: 6.7888e-07 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 29/30
# 45/45 [==============================] - 20s 444ms/step - loss: 0.0101 - accuracy: 0.9972 - val_loss: 0.0820 - val_accuracy: 0.9719
# Epoch 30/30
# 45/45 [==============================] - 20s 443ms/step - loss: 6.4699e-06 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], label="Training accuracy")
plt.plot(history.history['val_accuracy'], label="Validation accuracy")
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Plot using Seaborn
my_plot = sns.lineplot(data=history[["Training loss","validation_loss"]])
my_plot.set_xlabel('Epochs')
my_plot.set_ylabel('Loss')
plt.legend(labels=["Training", "Validation"])
plt.title('Training and Validation Loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-cc805bdc2e0e> in <module>()
#       8 plt.show()
#       9 # Plot using Seaborn
# ---> 10 my_plot = sns.lineplot(data=history[["Training loss","validation_loss"]])
#      11 my_plot.set_xlabel('Epochs')
#      12 my_plot.set_ylabel('Loss')
#
# TypeError: 'History' object is not subscriptable

# %%
model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 2s 178ms/step - loss: 0.0024 - accuracy: 1.0000
# [0.0023827010300010443, 1.0]

# %%
model.save('brain_tumor.h5')

# %%
import numpy as np
import pandas as pd
y_test.shape
# Out:
# (293, 2)

# %%
y_pred = model.predict(X_test, verbose=0)
y_pred.shape
# Out:
# (293, 2)

# %%
from sklearn.metrics import confusion_matrix
c_matrix = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))

# %%
import seaborn as sns
def confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    """Prints a confusion matrix, as returned by sklearn.metrics.confusion_matrix, as a heatmap.
    
    Arguments
    ---------
    confusion_matrix: numpy.ndarray
        The numpy.ndarray object returned from a call to sklearn.metrics.confusion_matrix. 
        Similarly constructed ndarrays can also be used.
    class_names: list
        An ordered list of class names, in the order they index the given confusion matrix.
    figsize: tuple
        A 2-long tuple, the first value determining the horizontal size of the ouputted figure,
        the second determining the vertical size. Defaults to (10,7).
    fontsize: int
        Font size for axes labels. Defaults to 14.
    """
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
class_names= batches.class_indices.keys()
confusion_matrix(c_matrix, class_names, figsize = (20,7), fontsize=14)

# %%
# From categorical outputs to discrete values

y_pred_ = [np.argmax(y) for y in y_pred]
y_test_ = [np.argmax(y) for y in y_test]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_, y_pred_))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       158
#            1       1.00      1.00      1.00       135
#
#     accuracy                           1.00       293
#    macro avg       1.00      1.00      1.00       293
# weighted avg       1.00      1.00      1.00       293

# %%
categories = {"HighGrade" : 0,
              "Low Grade"  : 1}
print(categories)
# Out:
# {'HighGrade': 0, 'Low Grade': 1}

# %%
def predict_class(img):
    # Resize
    img = img.reshape(1,256,256,3)
    # Predict
    predictions = model.predict(img)
    true_prediction = [tf.argmax(pred) for pred in predictions]
    true_prediction = np.array(true_prediction)
    
    # Return label corresponding to predicted index
    return list(categories.keys())[list(categories.values()).index(true_prediction)]

# %%
predict_class(X_test[0])
# Out:
# 'Low Grade'

# %%
plt.figure(figsize=(10,10))
random_inds = np.random.choice(X_test.shape[0],36)
for i in range(36):
    plt.subplot(6,6,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    image_ind = random_inds[i]
    plt.imshow(np.squeeze(X_test[image_ind]), cmap=plt.cm.binary)
    
    # Predict and get label
    label = predict_class(X_test[image_ind])
    plt.xlabel(label)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
